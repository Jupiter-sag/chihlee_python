# %%
students={'chinsese':89,
          'english':94,
          'math':65,
          'history':92,
          'discover':95}
for key in students:
    print(students[key])
# Out:
# 89
# 94
# 65
# 92
# 95
